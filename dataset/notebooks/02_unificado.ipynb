# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("df_unificado.csv")

# %%
df = df.drop(columns="fuente")

# %%
df.head(5)
# Out:
#                                               titulo  \
# 0          Tech Execs Face Congress: 9 Big Takeaways
# 1  How to Be Productive and Creative in Times of ...
# 2  House Reports Claims Anticompetitive Behavior ...
# 3            Exploring Your Mobile App Business Idea
# 4       NEXT 2018 — Google crossing the cloud chasm?
#
#                                                texto             categoria  \
# 0  Apple’s Tim Cook, Google’s Sundar Pichai, Amaz...  Programación General
# 1  How to Be Productive and Creative in Times of ...              Frontend
# 2  “Our investigation leaves no doubt that there ...  Programación General
# 3  An actionable post to get going with your mobi...                Mobile
# 4  Last week I had a great time at NEXT in San Fr...        DevOps / Cloud
#
#                                       palabras_clave       nivel
# 0  ['Apple', 'Business', 'Google', 'Facebook', 'A...  Intermedio
# ...

# %%
df.to_csv("df_unificado.csv", index=False, encoding="utf-8")
